# %%
import os
import sys

# data science
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import seaborn as sns

# signal processing
from scipy import signal
from scipy.ndimage import label
from scipy.stats import zscore
from scipy.interpolate import interp1d
from scipy.integrate import trapz

# physionet data
# import wfdb
# from wfdb import processing

# %%
project_path = os.path.join(os.getcwd(), os.pardir)
data_path = os.path.join(project_path, 'data')
output_path = os.path.join(project_path, 'output')

# style settings
sns.set(style='whitegrid', rc={'axes.facecolor': '#EFF2F7'})

# sample frequency for Bobbi sensor
settings = {}
settings['fs'] = 500

# %%
def get_plot_ranges(start=10, end=20, n=5):
    '''
    Make an iterator that divides into n or n+1 ranges. 
    - if end-start is divisible by steps, return n ranges
    - if end-start is not divisible by steps, return n+1 ranges, where the last range is smaller and ends at n
    
    # Example:
    >> list(get_plot_ranges())
    >> [(0.0, 3.0), (3.0, 6.0), (6.0, 9.0)]

    '''
    distance = end - start
    for i in np.arange(start, end, np.floor(distance/n)):
        yield (int(i), int(np.minimum(end, np.floor(distance/n) + i)))

# %%
def group_peaks(p, threshold=5):
    '''
    The peak detection algorithm finds multiple peaks for each QRS complex. 
    Here we group collections of peaks that are very near (within threshold) and we take the median index 
    '''
    # initialize output
    output = np.empty(0)

    # label groups of sample that belong to the same peak
    peak_groups, num_groups = label(np.diff(p) < threshold)

    # iterate through groups and take the mean as peak index
    for i in np.unique(peak_groups)[1:]:
        peak_group = p[np.where(peak_groups == i)]
        output = np.append(output, np.median(peak_group))
    return output

# %%
def detect_peaks(ecg_signal, threshold=0.3, qrs_filter=None):
    '''
    Peak detection algorithm using cross corrrelation and threshold 
    '''
    if qrs_filter is None:
        # create default qrs filter
        t = np.linspace(1.5 * np.pi, 3.5 * np.pi, 15)
        qrs_filter = np.sin(t)
    
    # normalize data
    ecg_signal = (ecg_signal - ecg_signal.mean()) / ecg_signal.std()

    # calculate cross correlation
    similarity = np.correlate(ecg_signal, qrs_filter, mode="same")
    similarity = similarity / np.max(similarity)

    # return peaks (values in ms) using threshold
#     print (ecg_signal[similarity > threshold][["'sample #'"]])
    return ecg_signal[similarity > threshold].index, similarity
#     return ecg_signal[similarity > threshold][["'sample #'"]], similarity

# %%
df = pd.read_csv("./mitbih_database/ecg.csv", sep=";", index_col="ms")
df1 = pd.read_csv("./mitbih_database/205.csv")
# print (df, type(df))
# print (df1, type(df1))

# print (df1[0:10].index)
# df1 = df1[["'V1'"]]
# print (df1, type(df1))

# %%
plt.figure(figsize=(40, 10))
start = 0
stop = 5000
# print (1, df[start:stop], type(df[start:stop].index))
df1.index = list(df1.index)
# print (2, df1[start:stop], type(df1[start:stop].index))
# print (df1[["'sample #'"]][start:stop])                 
# start = 700
# stop = 1300
duration = (stop-start) / settings['fs']
plt.title("ECG signal, slice of %.1f seconds" % duration, fontsize=24)
plt.plot(df[start:stop].index, df[start:stop].heartrate, color="#51A6D8", linewidth=1)

# plt.plot(df1[start:stop].index, df1["'V1'"][start:stop], color="olive", linewidth=1)

plt.xlabel("Time (ms)", fontsize=16)
plt.ylabel("Amplitude (arbitrary unit)", fontsize=16)
# Out:
# Text(0, 0.5, 'Amplitude (arbitrary unit)')

# %%
sampfrom = 60000
sampto = 70000
nr_plots = 1

for start, stop in get_plot_ranges(sampfrom, sampto, nr_plots):
    # get slice data of ECG data
    cond_slice = (df.index >= start) & (df.index < stop) 
    ecg_slice = df.heartrate[cond_slice]
#     print (1, ecg_slice.shape, type(ecg_slice))
#     print (ecg_slice)
    
#     cond_slice = (df1.index >= start) & (df1.index < stop)
#     ecg_slice = df1["'V1'"][cond_slice]
#     ecg_slice = ecg_slice.values.flatten()
#     ecg_slice = pd.Series(ecg_slice)
#     print (2, ecg_slice.shape, type(ecg_slice))
#     print (ecg_slice)

    # detect peaks
    peaks, similarity = detect_peaks(ecg_slice, threshold=0.3)
    
    # plot similarity
    plt.figure(figsize=(40, 20))
    
#     plt.subplot(212)
#     plt.title('Similarity with QRS template', fontsize=24)
#     plt.plot(ecg_slice.index, similarity, label="Similarity with QRS filter", color="olive", linewidth=1)
#     plt.legend(loc="upper right", fontsize=20)
#     plt.xlabel("Time (milliseconds)", fontsize=16)
#     plt.ylabel("Similarity (normalized)", fontsize=16)

    plt.subplot(211)
    plt.title("ECG signal with found peaks", fontsize=24)
    plt.plot(ecg_slice.index, ecg_slice, label="ECG", color="#51A6D8", linewidth=1)
    plt.plot(peaks, np.repeat(600, peaks.shape[0]), markersize=10, label="peaks", color="orange", marker="o", linestyle="None")
    plt.legend(loc="upper right", fontsize=20)
    plt.xlabel("Time (milliseconds)", fontsize=16)
    plt.ylabel("Amplitude (arbitrary unit)", fontsize=16)

#     plt.savefig(, "peaks-%s-%s.png" % (start, stop)))

# %%
# peaks, similarity = detect_peaks(df.heartrate, threshold=0.3)
# # peaks, similarity = detect_peaks(df1["'V1'"], threshold=0.3)

# # group peaks so we get a single peak per beat (hopefully)
# grouped_peaks = group_peaks(peaks)

# # RR-intervals are the differences between successive peaks
# rr = np.diff(grouped_peaks)

# # plot RR-intervals
# plt.figure(figsize=(40, 15))
# plt.title("RR-intervals", fontsize=24)
# plt.xlabel("Time (ms)", fontsize=16)
# plt.ylabel("RR-interval (ms)", fontsize=16)

# plt.plot(np.cumsum(rr), rr, label="RR-interval", color="#A651D8", linewidth=2)

# %%
# plt.figure(figsize=(40, 10))
# plt.title("Distribution of RR-intervals", fontsize=24)
# sns.kdeplot(rr, label="rr-intervals", color="#A651D8", shade=True)

# outlier_low = np.mean(rr)-2 * np.std(rr)
# outlier_high = np.mean(rr)+2 * np.std(rr)

# plt.axvline(x=outlier_low)
# plt.axvline(x=outlier_high, label="outlier boundary")
# plt.text(outlier_low - 270, 0.004, "outliers low (< mean - 2 sigma)", fontsize=20)
# plt.text(outlier_high + 20, 0.004, "outliers high (> mean + 2 sigma)", fontsize=20)

# plt.xlabel("RR-interval (ms)", fontsize=16)
# plt.ylabel("Density", fontsize=16)

# plt.legend(fontsize=24)

# %%
# plt.figure(figsize=(40, 15))

# rr_corrected = rr.copy()
# rr_corrected[np.abs(zscore(rr)) > 2] = np.median(rr)

# plt.title("RR-intervals", fontsize=24)
# plt.xlabel("Time (ms)", fontsize=16)
# plt.ylabel("RR-interval (ms)", fontsize=16)

# plt.plot(rr, color="red", linewidth=1, label="RR-intervals")
# plt.plot(rr_corrected, color="green", linewidth=2, label="RR-intervals after correction")
# plt.legend(fontsize=20)

# %%
sampfrom = 200000
sampto = 250000
nr_plots = 1

# detect peaks
peaks, similarity = detect_peaks(df.heartrate, threshold=0.3)
# peaks, similarity = detect_peaks(df1["'V1'"], threshold=0.3)
# print (peaks[0:50], rr[0:50])

# group peaks so we get a single peak per beat (hopefully)
grouped_peaks = group_peaks(peaks)

# RR-intervals are the differences between successive peaks
rr = np.diff(grouped_peaks)

for start, stop in get_plot_ranges(sampfrom, sampto, nr_plots):
    # plot similarity
    plt.figure(figsize=(40, 20))

    plt.title("ECG signal & RR-intervals", fontsize=24)
    plt.plot(df.index, df.heartrate, label="ECG", color="#51A6D8", linewidth=1)
#     plt.plot(df1.index, df1["'V1'"], label="ECG", color="#51A6D8", linewidth=1)
    plt.plot(grouped_peaks, np.repeat(600, grouped_peaks.shape[0]), markersize=14, label="Found peaks", color="orange", marker="o", linestyle="None")
    plt.legend(loc="upper left", fontsize=20)
    plt.xlabel("Time (milliseconds)", fontsize=16)
    plt.ylabel("Amplitude (arbitrary unit)", fontsize=16)
    plt.gca().set_ylim(400, 800)
    
    ax2 = plt.gca().twinx()
    ax2.plot(np.cumsum(rr)+peaks[0], rr, label="RR-intervals", color="#A651D8", linewidth=2, markerfacecolor="#A651D8", markeredgewidth=0, marker="o", markersize=18)
#     print (np.cumsum(rr)+peaks[0], rr)
    ax2.set_xlim(start, stop)
    ax2.set_ylim(-2000, 2000)
    ax2.legend(loc="upper right", fontsize=20)

    plt.xlabel("Time (ms)", fontsize=16)
    plt.ylabel("RR-interval (ms)", fontsize=16)
    
# ax2 = plt.gca().twinx()
# ax2.plot(69, 71, label="RR-intervals", color="#A651D8", linewidth=2, markerfacecolor="#A651D8", markeredgewidth=0, marker="o", markersize=18)
# ax2.set_xlim(start, stop)
# ax2.set_ylim(-2000, 2000)
# ax2.legend(loc="upper right", fontsize=20)
    
#     plt.savefig(os.path.join(output_path, "ecg-with-rr-%s-%s.png" % (start, stop)))

# %%
# print ((np.cumsum(rr)+peaks[0])[0:20], len(np.cumsum(rr)+peaks[0]))
# print (rr[0:20], len(rr))
# plt.figure(figsize=(40, 10))
# # start = 0
# # stop = 5000
# a = 0

# # for i in (np.cumsum(rr) + peaks[0]):
# #     start = i - 300
# #     stop = i + 300
# #     while a < 1:
# #         print (i, start, stop)
# #         duration = (stop-start) / settings['fs']
# #         plt.title("ECG signal, slice of %.1f seconds" % duration, fontsize=24)
# #         plt.plot(df[start:stop].index, df[start:stop].heartrate, color="#51A6D8", linewidth=1)
# #         plt.xlabel("Time (ms)", fontsize=16)
# #         a += 1

# start = 1867
# stop = 2167
# duration = (stop-start) / settings['fs']
# plt.title("ECG signal, slice of %.1f seconds" % duration, fontsize=24)
# plt.plot(df[start:stop].index, df[start:stop].heartrate, color="#51A6D8", linewidth=1)
# # plt.plot(df1[start:stop].index, df1["'V1'"][start:stop], color="#51A6D8", linewidth=1)
# plt.xlabel("Time (ms)", fontsize=16)
# plt.ylabel("Amplitude (arbitrary unit)", fontsize=16)

# %%
df = pd.read_csv('./mitbih_database/205annotations.txt')

# print (df)

# df = df["Sample #"].to_numpy()
# print (df)

# import numpy as np
df = pd.read_table('./mitbih_database/205annotations.txt', delim_whitespace=True, header=None)
# print (df)
data = df.iloc[:,:-1].values.tolist()
target = df.iloc[:,1].tolist()
output = df.iloc[:,2].tolist()
# print (target, type(target))
target = target[2:]
output = output[2:]

# print (np.intersect1d(target, peaks))

# print ((target))
# print (output)

# %%
import csv

df = pd.read_csv('./mitbih_database/205annotations.txt')

# print (df)

# df = df["Sample #"].to_numpy()
# print (df)

# import numpy as np
df = pd.read_table('./mitbih_database/205annotations.txt', delim_whitespace=True, header=None)
print (df)
data = df.iloc[:,:-1].values.tolist()
target = df.iloc[:,1].tolist()
output = df.iloc[:,2].tolist()
# print (target, type(target))
target = target[2:]
output = output[2:]

df = pd.read_table('./mitbih_database/205.csv')
print(df, type(df))

new_data = []

for it in range(0, len(target)):
    val = int(target[it])
    low = val - 24
    high = val + 25
    lst = []
    for j in range(low, high + 1):
        dt = df.iloc[j].values
        string = dt.item(0)
        sample = -1
        MLII = -1
        V1 = -1
        index = 0

        while index < len(string):
            start = index
            while(index < len(string) and string[index] != ','):
                index += 1
            s = string[start:index]
        #     print (s)
            index += 1
            if (sample == -1):
                sample = int(s)
            elif (MLII == -1):
                MLII = int(s)
            else:
                V1 = int(s)

#         print (sample, MLII, V1)
        lst.append(V1)
#         print (len(lst))
    lst.append(output[it])
    new_data.append(lst)

    with open("./New Data/new_data.csv", 'a', newline='') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(lst)
#     print (lst)
#     print (len(lst))

print (len(new_data))
# print (new_data[0], new_data[1], new_data[2])


# dt = df.iloc[229].values
# string = dt.item(0)
# print((dt.item(0)))
# sample = -1
# MLII = -1
# V1 = -1
# index = 0

# while index < len(string):
#     start = index
#     while(index < len(string) and string[index] != ','):
#         index += 1
#     s = string[start:index]
# #     print (s)
#     index += 1
#     if (sample == -1):
#         sample = int(s)
#     elif (MLII == -1):
#         MLII = int(s)
#     else:
#         V1 = int(s)

# print (sample, MLII, V1)
# Out:
#        'sample #','MLII','V1'
# 0                   0,938,916
# 1                   1,938,916
# 2                   2,938,916
# 3                   3,938,916
# 4                   4,938,916
# ...                       ...
# 649995         649995,953,952
# 649996         649996,952,949
# 649997         649997,951,951
# 649998         649998,949,948
# 649999       649999,1024,1024
#
# [650000 rows x 1 columns] <class 'pandas.core.frame.DataFrame'>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-ae02bccd9edf> in <module>
#       6 new_data = []
#       7
# ----> 8 for it in range(0, len(target)):
#       9     val = int(target[it])
#      10     low = val - 24
#
# NameError: name 'target' is not defined

# %%
import csv

# %%
i = 100
while i < 122:
    filename = './mitbih_database/' + str(i) + 'annotations.txt'
    df = pd.read_csv(filename)
    df = pd.read_table(filename, delim_whitespace=True, header=None)
#     print (df)
    data = df.iloc[:,:-1].values.tolist()
    target = df.iloc[:,1].tolist()
    output = df.iloc[:,2].tolist()
    # print (target, type(target))
    target = target[10:]
    output = output[10:]
    
    filename = './mitbih_database/' + str(i) + '.csv'
    df = pd.read_table(filename)
    new_data = []

    for it in range(0, len(target)):
        val = int(target[it])
        low = val - 24
        high = val + 25
        if (high > 639999):
            break
        lst = []
        for j in range(low, high + 1):
            dt = df.iloc[j].values
            string = dt.item(0)
            sample = -1
            MLII = -1
            V1 = -1
            index = 0

            while index < len(string):
                start = index
                while(index < len(string) and string[index] != ','):
                    index += 1
                s = string[start:index]
            #     print (s)
                index += 1
                if (sample == -1):
                    sample = int(s)
                elif (MLII == -1):
                    MLII = int(s)
                else:
                    V1 = int(s)

    #         print (sample, MLII, V1)
            lst.append(V1)
    #         print (len(lst))
        lst.append(output[it])
        new_data.append(lst)

        with open("./New Data/new_data.csv", 'a', newline='') as myfile:
            wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
            wr.writerow(lst)
    #     print (lst)
    #     print (len(lst))

    print (len(new_data))
    i += 1
# Out:
# 2227
# 1838
# 2149
# 2051
# 2268
# 2643
# 2051
# 2098
# 1782
# 2487
# 2090
# 2502
# 1758
# 1846
# 1920
# 2373
# 1506
# 2254
# 2055
# 1833
# 2430
# 1484

# %%
i = 200
while i < 224:
    filename = './mitbih_database/' + str(i) + 'annotations.txt'
    df = pd.read_csv(filename)
    df = pd.read_table(filename, delim_whitespace=True, header=None)
#     print (df)
    data = df.iloc[:,:-1].values.tolist()
    target = df.iloc[:,1].tolist()
    output = df.iloc[:,2].tolist()
    # print (target, type(target))
    target = target[10:]
    output = output[10:]
    
    filename = './mitbih_database/' + str(i) + '.csv'
    df = pd.read_table(filename)
    new_data = []

    for it in range(0, len(target)):
        val = int(target[it])
        low = val - 24
        high = val + 25
        if (high > 639999):
            break
        lst = []
        for j in range(low, high + 1):
            dt = df.iloc[j].values
            string = dt.item(0)
            sample = -1
            MLII = -1
            V1 = -1
            index = 0

            while index < len(string):
                start = index
                while(index < len(string) and string[index] != ','):
                    index += 1
                s = string[start:index]
            #     print (s)
                index += 1
                if (sample == -1):
                    sample = int(s)
                elif (MLII == -1):
                    MLII = int(s)
                else:
                    V1 = int(s)

    #         print (sample, MLII, V1)
            lst.append(V1)
    #         print (len(lst))
        lst.append(output[it])
        new_data.append(lst)

        with open("./New Data/new_data.csv", 'a', newline='') as myfile:
            wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
            wr.writerow(lst)
    #     print (lst)
    #     print (len(lst))

    print (len(new_data), i)
    i += 1
# Out:
# 2740 200
# 2000 201
# 2097 202
# 3056 203
# 2321 204
# 2625 205
# 2986 206
# 3000 207
# 2634 208
# 2715 209
# 3235 210
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-33ecce69fad9> in <module>()
#       3     filename = './mitbih_database/' + str(i) + 'annotations.txt'
#       4     df = pd.read_csv(filename)
# ----> 5     df = pd.read_table(filename, delim_whitespace=True, header=None)
#       6 #     print (df)
#       7     data = df.iloc[:,:-1].values.tolist()
#
# /home/suyash/.local/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# /home/suyash/.local/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     461
#     462     try:
# --> 463         data = parser.read(nrows)
#     464     finally:
#     465         parser.close()
#
# /home/suyash/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1152     def read(self, nrows=None):
#    1153         nrows = _validate_integer("nrows", nrows)
# -> 1154         ret = self._engine.read(nrows)
#    1155
#    1156         # May alter columns / col_dict
#
# /home/suyash/.local/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2057     def read(self, nrows=None):
#    2058         try:
# -> 2059             data = self._reader.read(nrows)
#    2060         except StopIteration:
#    2061             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: EOF inside string starting at row 413

# %%
df = pd.read_csv("./New Data/new_data.csv")
# print (df)

for i in range(0, 82269):
    if df["Output"][i] != 'N':
        df["Output"][i] = 'A'

print (df["Output"])
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0        N
# 1        N
# 2        N
# 3        N
# 4        N
#         ..
# 82264    N
# 82265    N
# 82266    A
# 82267    N
# 82268    A
# Name: Output, Length: 82269, dtype: object

# %%
with open("./New Data/output.csv", 'w') as myfile:
    wr = csv.writer(myfile, delimiter=',', lineterminator='\n')
    wr.writerow(df["Output"])

# %%
print(df["Output"])
# Out:
# N

# %%
csv_file = input('./New Data/output.csv')
txt_file = input('./New Data/output.txt')
with open(txt_file, "w") as my_output_file:
    with open(csv_file, "r") as my_input_file:
        [ my_output_file.write(" ".join(row)+'\n') for row in csv.reader(my_input_file)]
    my_output_file.close()
# Out:
# ./New Data/output.csv./New Data/output.csv
# ./New Data/output.txt./New Data/output.txt

# %%
df["Output"].to_csv("./New Data/dfTest.csv","\t", header=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-65bc1696762e> in <module>()
# ----> 1 df["Output"].flatten().to_csv("./New Data/dfTest.csv","\t",header=False)
#
# /home/suyash/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'flatten'

# %%
df = pd.read_csv("./New Data/new_data.csv")

df = df[0:10000]
print (df[0:10000])

for row in df:
    print (row)
with open("./New Data/halfdata.csv", 'w', newline='') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
    wr.writerow(df)
# Out:
#         S1    S2    S3    S4    S5    S6    S7    S8    S9   S10  ...   S46  \
# 0      924   923   923   923   920   918   917   917   918   921  ...   921
# 1      926   926   929   929   927   927   927   924   924   923  ...   920
# 2      931   933   934   938   934   933   932   931   927   928  ...   928
# 3      924   926   927   929   930   932   931   931   930   927  ...   925
# 4      932   933   932   932   931   930   926   926   929   928  ...   928
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# 9995  1022  1021  1018  1016  1017  1021  1021  1017  1016  1015  ...  1017
# 9996  1015  1014  1014  1018  1016  1018  1015  1016  1015  1018  ...  1015
# 9997  1013  1011  1014  1016  1016  1014  1012  1015  1016  1016  ...  1015
# 9998  1014  1014  1012  1015  1019  1020  1016  1017  1015  1017  ...  1015
# 9999  1011  1014  1016  1016  1012  1012  1014  1016  1017  1017  ...  1011
#
#        S47   S48   S49   S50  PreRR  PostRR  LocalRR  GlobalRR  Output
# 0      922   924   926   925    917     918      921       921       N
# 1      923   924   925   926    924     924      923       922       N
# 2      927   929   928   930    931     927      928       926       N
# 3      922   924   922   922    931     930      927       925       N
# 4      929   929   932   934    926     929      928       927       N
# ...    ...   ...   ...   ...    ...     ...      ...       ...     ...
# 9995  1022  1023  1022  1021   1017    1016     1015      1019       N
# 9996  1016  1016  1016  1014   1016    1015     1018      1017       N
# 9997  1015  1012  1013  1013   1015    1016     1016      1016       N
# 9998  1020  1018  1016  1014   1017    1015     1017      1019       N
# 9999  1012  1010  1008  1011   1016    1017     1017      1014       N
#
# [10000 rows x 55 columns]
# S1
# S2
# S3
# S4
# S5
# S6
# S7
# S8
# S9
# S10
# S11
# S12
# S13
# S14
# S15
# S16
# S17
# S18
# S19
# S20
# S21
# S22
# S23
# S24
# S25
# S26
# S27
# S28
# S29
# S30
# S31
# S32
# S33
# S34
# S35
# S36
# S37
# S38
# S39
# S40
# S41
# S42
# S43
# S44
# S45
# S46
# S47
# S48
# S49
# S50
# PreRR
# PostRR
# LocalRR
# GlobalRR
# Output

# %%
df = pd.read_csv("./New Data/new_data.csv")
dt = df.iloc[1].values
print (dt, type(dt))


numN = 0
numA = 0
i = 0
while numN < 2288:
    dt = df.iloc[i].values
    if dt[len(dt) - 1] == 'N':
        with open("./New Data/training.csv", 'a', newline='') as myfile:
            wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
            wr.writerow(dt)
        numN += 1
    i += 1
    
i = 0
while numA < 2288:
    dt = df.iloc[i].values
    if dt[len(dt) - 1] == 'A':
        with open("./New Data/training.csv", 'a', newline='') as myfile:
            wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
            wr.writerow(dt)
        numA += 1
    i += 1

        
if dt[len(dt) - 1] == 'N':
    print ("safa")
# Out:
# [926 926 929 929 927 927 927 924 924 923 922 924 926 926 929 931 927 922
#  914 903 892 877 869 868 871 881 894 912 928 939 944 945 937 928 921 915
#  915 916 920 925 926 927 923 923 922 920 923 924 925 926 924 924 923 922
#  'N'] <class 'numpy.ndarray'>

# %%
df = pd.read_csv("./New Data/training.csv")
# print (df[0:10])
ds = df.sample(frac=1)
# print (ds[0:10])
i = 0
while i < 4575:
    dt = ds.iloc[i].values
    with open("./New Data/trainingSet.csv", 'a', newline='') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(dt)
    i += 1
