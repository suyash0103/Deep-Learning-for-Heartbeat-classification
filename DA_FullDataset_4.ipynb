# %% [markdown]
# <a href="https://colab.research.google.com/github/suyash0103/Deep-Learning-for-Heartbeat-classification/blob/master/DA_FullDataset_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = '/content/gdrive/My Drive/DA Project/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir(root_path)
os.listdir()
# Out:
# ['dataset.csv',
#  'modifiedDNN.h5',
#  'dnnModel.h5',
#  'train.csv',
#  'x_test.npy',
#  'X_testModifiedDNN.npy',
#  'y_test.npy',
#  'Y_testModifiedDNN.npy',
#  'new_data.csv',
#  'training_set.csv',
#  'shuffledTraining10000.csv',
#  'dnnModel82K.h5',
#  'x_test_82k.npy',
#  'y_test_82k.npy']

# %%
import pandas as pd
import numpy as np

df = pd.read_csv(root_path+'new_data.csv')

# %%
df.head()
# Out:
#     S1   S2   S3   S4   S5   S6  ...  S50  PreRR  PostRR  LocalRR  GlobalRR  Output
# 0  924  923  923  923  920  918  ...  925    917     918      921       921       N
# 1  926  926  929  929  927  927  ...  926    924     924      923       922       N
# 2  931  933  934  938  934  933  ...  930    931     927      928       926       N
# 3  924  926  927  929  930  932  ...  922    931     930      927       925       N
# 4  932  933  932  932  931  930  ...  934    926     929      928       927       N
#
# [5 rows x 55 columns]

# %%
df.shape
# Out:
# (82269, 55)

# %%
Y = df['Output']

# %%
df1 = df.drop(['Output'], axis=1)

# %%
X = df1

# %%
print(X.shape)
print(Y.shape)
# Out:
# (82269, 54)
# (82269,)

# %%
X.head()
# Out:
#     S1   S2   S3   S4   S5   S6  ...  S49  S50  PreRR  PostRR  LocalRR  GlobalRR
# 0  924  923  923  923  920  918  ...  926  925    917     918      921       921
# 1  926  926  929  929  927  927  ...  925  926    924     924      923       922
# 2  931  933  934  938  934  933  ...  928  930    931     927      928       926
# 3  924  926  927  929  930  932  ...  922  922    931     930      927       925
# 4  932  933  932  932  931  930  ...  932  934    926     929      928       927
#
# [5 rows x 54 columns]

# %%
Y.head()
# Out:
# 0    N
# 1    N
# 2    N
# 3    N
# 4    N
# Name: Output, dtype: object

# %%
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
model = Sequential()
model.add(Dense(5, input_dim=54, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(40, activation='relu'))
model.add(Dense(30, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3657: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 5)                 275
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                60
# _________________________________________________________________
# dense_3 (Dense)              (None, 30)                330
# _________________________________________________________________
# dense_4 (Dense)              (None, 40)                1240
# _________________________________________________________________
# dense_5 (Dense)              (None, 50)                2050
# _________________________________________________________________
# dense_6 (Dense)              (None, 40)                2040
# _________________________________________________________________
# dense_7 (Dense)              (None, 30)                1230
# ...

# %%
ZZ= Y

# %%
from random import randint
for i in range(len(ZZ)):
  if ZZ[i] == 'A':
    ZZ[i] = 0

  else:
    ZZ[i] = 1
    # print(yk)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
ZZ.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: Output, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, ZZ, test_size=0.2, shuffle = True)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, ZZ, test_size=0.2, shuffle = True)
X_train3, X_test3, y_train3, y_test3 = train_test_split(X, ZZ, test_size=0.2, shuffle = True)
X_train4, X_test4, y_train4, y_test4 = train_test_split(X, ZZ, test_size=0.2, shuffle = True)
X_train5, X_test5, y_train5, y_test5 = train_test_split(X, ZZ, test_size=0.2, shuffle = True)

# %%
model.fit(X_train1, y_train1, epochs=100, batch_size=64)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/100
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# ...

# %%
_, accuracy1 = model.evaluate(X_test1, y_test1, verbose=0)
accuracy1
# Out:
# 0.9146104290677519

# %%
model.fit(X_train2, y_train2, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2781 - acc: 0.9047
# Epoch 2/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2789 - acc: 0.9047
# Epoch 3/100
# 65815/65815 [==============================] - 2s 33us/step - loss: 0.2757 - acc: 0.9058
# Epoch 4/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2789 - acc: 0.9050
# Epoch 5/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2800 - acc: 0.9045
# Epoch 6/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2808 - acc: 0.9033
# Epoch 7/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2776 - acc: 0.9055
# Epoch 8/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2771 - acc: 0.9055
# Epoch 9/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2761 - acc: 0.9056
# Epoch 10/100
# ...

# %%
_, accuracy2 = model.evaluate(X_test2, y_test2, verbose=0)
accuracy2
# Out:
# 0.8971070864227544

# %%
model.fit(X_train3, y_train3, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 65815/65815 [==============================] - 2s 32us/step - loss: 0.2732 - acc: 0.9068
# Epoch 2/100
# 65815/65815 [==============================] - 2s 33us/step - loss: 0.2755 - acc: 0.9064
# Epoch 3/100
# 65815/65815 [==============================] - 2s 33us/step - loss: 0.2804 - acc: 0.9035
# Epoch 4/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2741 - acc: 0.9065
# Epoch 5/100
# 65815/65815 [==============================] - 2s 32us/step - loss: 0.2746 - acc: 0.9065
# Epoch 6/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2784 - acc: 0.9056
# Epoch 7/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2716 - acc: 0.9073
# Epoch 8/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2734 - acc: 0.9071
# Epoch 9/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2751 - acc: 0.9065
# Epoch 10/100
# ...

# %%
_, accuracy3 = model.evaluate(X_test3, y_test3, verbose=0)
accuracy3
# Out:
# 0.9098091649446943

# %%
model.fit(X_train4, y_train4, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2703 - acc: 0.9095
# Epoch 2/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2710 - acc: 0.9094
# Epoch 3/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2701 - acc: 0.9098
# Epoch 4/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2716 - acc: 0.9087
# Epoch 5/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2709 - acc: 0.9092
# Epoch 6/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2724 - acc: 0.9086
# Epoch 7/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2686 - acc: 0.9099
# Epoch 8/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2700 - acc: 0.9094
# Epoch 9/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2710 - acc: 0.9092
# Epoch 10/100
# ...

# %%
_, accuracy4 = model.evaluate(X_test4, y_test4, verbose=0)
accuracy4
# Out:
# 0.9059195332441959

# %%
model.fit(X_train5, y_train5, epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 65815/65815 [==============================] - 2s 32us/step - loss: 0.2713 - acc: 0.9091
# Epoch 2/100
# 65815/65815 [==============================] - 2s 32us/step - loss: 0.2741 - acc: 0.9079
# Epoch 3/100
# 65815/65815 [==============================] - 2s 32us/step - loss: 0.2712 - acc: 0.9093
# Epoch 4/100
# 65815/65815 [==============================] - 2s 33us/step - loss: 0.2715 - acc: 0.9089
# Epoch 5/100
# 65815/65815 [==============================] - 2s 32us/step - loss: 0.2697 - acc: 0.9098
# Epoch 6/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2711 - acc: 0.9090
# Epoch 7/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2697 - acc: 0.9101
# Epoch 8/100
# 65815/65815 [==============================] - 2s 30us/step - loss: 0.2701 - acc: 0.9092
# Epoch 9/100
# 65815/65815 [==============================] - 2s 31us/step - loss: 0.2684 - acc: 0.9105
# Epoch 10/100
# ...

# %%
_, accuracy5 = model.evaluate(X_test5, y_test5, verbose=0)
accuracy5
# Out:
# 0.9150358575422389

# %%
accuracy = (accuracy1 + accuracy2 + accuracy3 + accuracy4 + accuracy5) / 5 
print (accuracy)
# Out:
# 0.908496414244327

# %%
# X_test = np.load(root_path+'x_test.npy',allow_pickle=True)
# y_test = np.load(root_path+'y_test.npy',allow_pickle=True)

# %%
# from keras.models import load_model
# model = load_model(root_path+'dnnModel.h5')

# %%
# _, accuracy = model.evaluate(X_test, y_test, verbose=0)
# accuracy
# Out:
# 0.9087152060289292

# %%
scores = model.evaluate(X_test, y_test, verbose=0)

# %%
# print (scores)

# %%
y_pre = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix as cm

# %%
yTest = []
for i in y_test:
  yTest.append(int(i))

# %%
y =[]
for i in y_pre:
  y.append(int(i))
